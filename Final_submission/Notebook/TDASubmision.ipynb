# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/the-data-alchemist-techweek-23/train.csv
# /kaggle/input/the-data-alchemist-techweek-23/test.csv
# /kaggle/input/the-data-alchemist-techweek-23/sample_solution.csv

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] 
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] 
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        returna
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number])
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]]
    columnNames = list(df)
    if len(columnNames) > 10:
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
df_train = pd.read_csv('/kaggle/input/the-data-alchemist-techweek-23/train.csv')

# %%
print(f"The train data set contains {df_train.shape[0]} rows and {df_train.shape[1]} cols")
# Out:
# The train data set contains 266 rows and 51 cols

# %%
nRowsRead = 'None'
df_train.dataframeName = 'FootballData.csv'
nRow, nCol = df_train.shape
df_train.head(5)
# Out:
#     id result Div        Date     HomeTeam     AwayTeam  Bet365 home odds  \
# 0   97      A  E0  29-10-2021       France      Belgium               2.1
# 1   86      H  E0  22-10-2021    Argentina  South Korea               1.5
# 2   46      D  E0  17-09-2021  Netherlands   Costa Rica               2.6
# 3  180      D  E0  28-12-2021      England  Netherlands               2.1
# 4  266      A  E0  26-02-2022     Cameroon          USA               2.4
#
#    Bet365 draw odds  Bet365 away odds  Bet&Win home odds  ...  \
# 0              3.20               3.5               2.05  ...
# 1              3.75               7.0               1.40  ...
# 2              3.25               2.6               2.30  ...
# 3              3.25               3.4               2.10  ...
# 4              3.25               2.8               2.40  ...
#
#    Betbrain max >2.5  Betbrain average >2.5  Betbrain max <2.5  \
# 0               2.40                   2.04               1.80
# 1               2.03                   1.91               1.91
# 2               2.32                   2.11               1.71
# 3               2.15                   2.02               1.76
# 4               2.20                   2.04               1.80
#
#    Betbrain average <2.5  Betbrain Asian bookies  \
# 0                   1.71                      29
# 1                   1.80                      27
# 2                   1.65                      26
# 3                   1.70                      23
# 4                   1.70                      19
#
#    Betbrain Asian home handicap  Betbrain max Asian home odds  \
# 0                         -0.25                          2.04
# 1                         -1.00                          1.95
# 2                          0.00                          2.00
# 3                         -0.25                          1.92
# 4                          0.00                          1.80
#
#    Betbrain average Asian home odds  Betbrain max Asian away odds  \
# 0                              1.94                          1.98
# 1                              1.88                          2.08
# 2                              1.92                          1.97
# 3                              1.88                          2.01
# 4                              1.76                          2.14
#
#    Betbrain average Asian away odds
# 0                              1.92
# 1                              1.96
# 2                              1.91
# 3                              1.98
# 4                              2.05
#
# [5 rows x 51 columns]

# %%
plotPerColumnDistribution(df_train, 52, 3)

# %%
plotCorrelationMatrix(df_train, 15)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:25: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only

# %%
plotScatterMatrix(df_train, 50, 10)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df_train['Div_Cat'] = labelencoder.fit_transform(df_train['Div'])
df_train['Date_Cat'] = labelencoder.fit_transform(df_train['Date'])
df_train['HomeTeam_Cat'] = labelencoder.fit_transform(df_train['HomeTeam'])
df_train['result_cat'] = labelencoder.fit_transform(df_train['result'])
list(labelencoder.classes_)
# Out:
# ['A', 'D', 'H']

# %%
df_train['AwayTeam_Cat'] = labelencoder.fit_transform(df_train['AwayTeam'])
df_train.drop(['Div','Date','HomeTeam','AwayTeam','result'],axis=1,inplace=True)

# %%
cor_matrix = df_train.corr().abs()
print(cor_matrix)
# Out:
#                                         id  Bet365 home odds  \
# id                                1.000000          0.035550
# Bet365 home odds                  0.035550          1.000000
# Bet365 draw odds                  0.124160          0.132768
# Bet365 away odds                  0.019072          0.566687
# Bet&Win home odds                 0.059714          0.986309
# Bet&Win draw odds                 0.028041          0.186237
# Bet&Win away odds                 0.023659          0.593774
# gamebookers home odds             0.035367          0.993317
# gamebookers draw odds             0.093806          0.141060
# gamebookers away odds             0.020949          0.580572
# Interwetten home odds             0.035243          0.985097
# Interwetten draw odds             0.209813          0.146067
# Interwetten away odds             0.073843          0.614537
# Ladbrokes home odds               0.026461          0.986445
# Ladbrokes draw odds               0.052654          0.156073
# Ladbrokes away odds               0.012524          0.595790
# Sportingbet home odds             0.036711          0.994484
# Sportingbet draw odds             0.109043          0.129698
# Sportingbet away odds             0.027626          0.572007
# Will Hill home odds               0.008005          0.989195
# Will Hill draw odds               0.131356          0.142105
# Will Hill away odds               0.023027          0.599656
# Stan James home odds              0.044501          0.991648
# Stan James draw odds              0.067446          0.163329
# Stan James away odds              0.011279          0.602495
# VC Bet home odds                  0.029719          0.990083
# VC Bet draw odds                  0.107764          0.142516
# VC Bet away odds                  0.018002          0.593097
# Betbrain 1X2 bookies              0.685158          0.036621
# Betbrain max home odds            0.025836          0.984913
# Betbrain average home odds        0.037043          0.996914
# Betbrain max draw odds            0.090230          0.156592
# Betbrain average draw odds        0.108536          0.152929
# Betbrain max away odds            0.003536          0.556206
# Betbrain average draw odds.1      0.028568          0.587681
# Betbrain over/under bookies       0.474948          0.041060
# Betbrain max >2.5                 0.084588          0.115573
# Betbrain average >2.5             0.011305          0.119635
# Betbrain max <2.5                 0.068496          0.136515
# Betbrain average <2.5             0.090651          0.139856
# Betbrain Asian bookies            0.445663          0.066442
# Betbrain Asian home handicap      0.002888          0.854360
# Betbrain max Asian home odds      0.045503          0.131586
# Betbrain average Asian home odds  0.052911          0.135605
# Betbrain max Asian away odds      0.046786          0.141575
# Betbrain average Asian away odds  0.045581          0.144956
# Div_Cat                                NaN               NaN
# Date_Cat                          0.231710          0.064319
# HomeTeam_Cat                      0.062827          0.067192
# result_cat                        0.093876          0.361026
# AwayTeam_Cat                      0.003878          0.191977
#
#                                   Bet365 draw odds  Bet365 away odds  \
# id                                        0.124160          0.019072
# Bet365 home odds                          0.132768          0.566687
# Bet365 draw odds                          1.000000          0.842207
# Bet365 away odds                          0.842207          1.000000
# Bet&Win home odds                         0.128503          0.563396
# Bet&Win draw odds                         0.954753          0.877345
# Bet&Win away odds                         0.836777          0.973532
# gamebookers home odds                     0.128251          0.561625
# gamebookers draw odds                     0.982339          0.860857
# gamebookers away odds                     0.844580          0.983955
# Interwetten home odds                     0.198582          0.619190
# Interwetten draw odds                     0.953874          0.845611
# Interwetten away odds                     0.830887          0.968270
# Ladbrokes home odds                       0.136634          0.568049
# Ladbrokes draw odds                       0.932162          0.856008
# Ladbrokes away odds                       0.825185          0.975950
# Sportingbet home odds                     0.118535          0.555343
# Sportingbet draw odds                     0.973703          0.855766
# Sportingbet away odds                     0.848720          0.982902
# Will Hill home odds                       0.135270          0.564926
# Will Hill draw odds                       0.946529          0.833149
# Will Hill away odds                       0.799309          0.966769
# Stan James home odds                      0.122581          0.557912
# Stan James draw odds                      0.955454          0.866046
# Stan James away odds                      0.825490          0.984045
# VC Bet home odds                          0.130731          0.564777
# VC Bet draw odds                          0.970835          0.859430
# VC Bet away odds                          0.822767          0.980693
# Betbrain 1X2 bookies                      0.058382          0.028561
# Betbrain max home odds                    0.092897          0.530503
# Betbrain average home odds                0.129573          0.566317
# Betbrain max draw odds                    0.970752          0.873693
# Betbrain average draw odds                0.982788          0.873951
# Betbrain max away odds                    0.856924          0.986988
# Betbrain average draw odds.1              0.844602          0.989210
# Betbrain over/under bookies               0.035488          0.041908
# Betbrain max >2.5                         0.754347          0.639700
# Betbrain average >2.5                     0.797174          0.679518
# Betbrain max <2.5                         0.836881          0.713133
# Betbrain average <2.5                     0.853599          0.728056
# Betbrain Asian bookies                    0.185631          0.079919
# Betbrain Asian home handicap              0.561132          0.870918
# Betbrain max Asian home odds              0.078107          0.124903
# Betbrain average Asian home odds          0.071391          0.120045
# Betbrain max Asian away odds              0.078390          0.131100
# Betbrain average Asian away odds          0.086809          0.138792
# Div_Cat                                        NaN               NaN
# Date_Cat                                  0.029037          0.051488
# HomeTeam_Cat                              0.177137          0.150711
# result_cat                                0.245922          0.368675
# AwayTeam_Cat                              0.033212          0.058628
#
#                                   Bet&Win home odds  Bet&Win draw odds  \
# id                                         0.059714           0.028041
# Bet365 home odds                           0.986309           0.186237
# Bet365 draw odds                           0.128503           0.954753
# Bet365 away odds                           0.563396           0.877345
# Bet&Win home odds                          1.000000           0.185629
# Bet&Win draw odds                          0.185629           1.000000
# Bet&Win away odds                          0.595333           0.870202
# gamebookers home odds                      0.986333           0.183667
# gamebookers draw odds                      0.140901           0.971654
# gamebookers away odds                      0.578435           0.879313
# Interwetten home odds                      0.978518           0.250889
# Interwetten draw odds                      0.140547           0.929365
# Interwetten away odds                      0.611603           0.849984
# Ladbrokes home odds                        0.981736           0.189023
# Ladbrokes draw odds                        0.159607           0.935431
# Ladbrokes away odds                        0.594270           0.861721
# Sportingbet home odds                      0.985309           0.177115
# Sportingbet draw odds                      0.128786           0.973643
# Sportingbet away odds                      0.569879           0.881173
# Will Hill home odds                        0.979453           0.187982
# Will Hill draw odds                        0.137795           0.941063
# Will Hill away odds                        0.597408           0.839967
# Stan James home odds                       0.984850           0.178029
# Stan James draw odds                       0.164469           0.957735
# Stan James away odds                       0.600262           0.862232
# VC Bet home odds                           0.981487           0.185681
# VC Bet draw odds                           0.139926           0.965080
# VC Bet away odds                           0.590565           0.861662
# Betbrain 1X2 bookies                       0.056710           0.007462
# Betbrain max home odds                     0.971444           0.154309
# Betbrain average home odds                 0.987976           0.186449
# Betbrain max draw odds                     0.157601           0.963339
# Betbrain average draw odds                 0.152370           0.974484
# Betbrain max away odds                     0.553552           0.888592
# Betbrain average draw odds.1               0.585055           0.878960
# Betbrain over/under bookies                0.064643           0.010707
# Betbrain max >2.5                          0.115154           0.721885
# Betbrain average >2.5                      0.122341           0.778054
# Betbrain max <2.5                          0.141340           0.815145
# Betbrain average <2.5                      0.141336           0.825602
# Betbrain Asian bookies                     0.077411           0.112795
# Betbrain Asian home handicap               0.848808           0.605997
# Betbrain max Asian home odds               0.123863           0.069433
# Betbrain average Asian home odds           0.127269           0.068348
# Betbrain max Asian away odds               0.135171           0.065676
# Betbrain average Asian away odds           0.139479           0.079609
# Div_Cat                                         NaN                NaN
# Date_Cat                                   0.075872           0.054619
# HomeTeam_Cat                               0.046601           0.176119
# result_cat                                 0.355854           0.248575
# AwayTeam_Cat                               0.191561           0.026832
#
#                                   Bet&Win away odds  gamebookers home odds  \
# id                                         0.023659               0.035367
# Bet365 home odds                           0.593774               0.993317
# Bet365 draw odds                           0.836777               0.128251
# Bet365 away odds                           0.973532               0.561625
# Bet&Win home odds                          0.595333               0.986333
# Bet&Win draw odds                          0.870202               0.183667
# Bet&Win away odds                          1.000000               0.589892
# gamebookers home odds                      0.589892               1.000000
# gamebookers draw odds                      0.846627               0.139802
# gamebookers away odds                      0.985913               0.577106
# Interwetten home odds                      0.647816               0.984274
# Interwetten draw odds                      0.835190               0.140018
# Interwetten away odds                      0.974418               0.610266
# Ladbrokes home odds                        0.596653               0.990806
# Ladbrokes draw odds                        0.830515               0.152282
# Ladbrokes away odds                        0.977679               0.592026
# Sportingbet home odds                      0.583583               0.994892
# Sportingbet draw odds                      0.846015               0.126346
# Sportingbet away odds                      0.985350               0.567930
# Will Hill home odds                        0.593341               0.993590
# Will Hill draw odds                        0.829750               0.137272
# Will Hill away odds                        0.973958               0.596005
# Stan James home odds                       0.585790               0.991592
# Stan James draw odds                       0.852043               0.159182
# Stan James away odds                       0.982748               0.598661
# VC Bet home odds                           0.593125               0.992194
# VC Bet draw odds                           0.844474               0.137689
# VC Bet away odds                           0.976032               0.588968
# Betbrain 1X2 bookies                       0.008708               0.037031
# Betbrain max home odds                     0.558655               0.983342
# Betbrain average home odds                 0.594174               0.996161
# Betbrain max draw odds                     0.849540               0.153484
# Betbrain average draw odds                 0.858751               0.149597
# Betbrain max away odds                     0.974531               0.551782
# Betbrain average draw odds.1               0.987400               0.583300
# Betbrain over/under bookies                0.023515               0.041183
# Betbrain max >2.5                          0.643543               0.113252
# Betbrain average >2.5                      0.685183               0.116511
# Betbrain max <2.5                          0.726088               0.132375
# Betbrain average <2.5                      0.735142               0.135150
# Betbrain Asian bookies                     0.098215               0.062443
# Betbrain Asian home handicap               0.887691               0.851511
# Betbrain max Asian home odds               0.111545               0.123924
# Betbrain average Asian home odds           0.102211               0.127590
# Betbrain max Asian away odds               0.108032               0.134062
# Betbrain average Asian away odds           0.119770               0.137856
# Div_Cat                                         NaN                    NaN
# Date_Cat                                   0.061809               0.063218
# HomeTeam_Cat                               0.154123               0.058007
# result_cat                                 0.373967               0.365681
# AwayTeam_Cat                               0.050371               0.186958
#
#                                   gamebookers draw odds  \
# id                                             0.093806
# Bet365 home odds                               0.141060
# Bet365 draw odds                               0.982339
# Bet365 away odds                               0.860857
# Bet&Win home odds                              0.140901
# Bet&Win draw odds                              0.971654
# Bet&Win away odds                              0.846627
# gamebookers home odds                          0.139802
# gamebookers draw odds                          1.000000
# gamebookers away odds                          0.857681
# Interwetten home odds                          0.208515
# Interwetten draw odds                          0.954659
# Interwetten away odds                          0.839965
# Ladbrokes home odds                            0.144874
# Ladbrokes draw odds                            0.949830
# Ladbrokes away odds                            0.838205
# Sportingbet home odds                          0.127800
# Sportingbet draw odds                          0.982983
# Sportingbet away odds                          0.862351
# Will Hill home odds                            0.143414
# Will Hill draw odds                            0.956802
# Will Hill away odds                            0.816594
# Stan James home odds                           0.131787
# Stan James draw odds                           0.970007
# Stan James away odds                           0.838722
# VC Bet home odds                               0.142104
# VC Bet draw odds                               0.977168
# VC Bet away odds                               0.833788
# Betbrain 1X2 bookies                           0.036831
# Betbrain max home odds                         0.103954
# Betbrain average home odds                     0.139539
# Betbrain max draw odds                         0.980577
# Betbrain average draw odds                     0.991485
# Betbrain max away odds                         0.869403
# Betbrain average draw odds.1                   0.857479
# Betbrain over/under bookies                    0.019158
# Betbrain max >2.5                              0.747261
# Betbrain average >2.5                          0.793066
# Betbrain max <2.5                              0.830917
# Betbrain average <2.5                          0.847353
# Betbrain Asian bookies                         0.163752
# Betbrain Asian home handicap                   0.570761
# Betbrain max Asian home odds                   0.100016
# Betbrain average Asian home odds               0.090360
# Betbrain max Asian away odds                   0.091229
# Betbrain average Asian away odds               0.107546
# Div_Cat                                             NaN
# Date_Cat                                       0.036408
# HomeTeam_Cat                                   0.183071
# result_cat                                     0.241779
# AwayTeam_Cat                                   0.033677
#
#                                   gamebookers away odds  ...  \
# id                                             0.020949  ...
# Bet365 home odds                               0.580572  ...
# Bet365 draw odds                               0.844580  ...
# Bet365 away odds                               0.983955  ...
# Bet&Win home odds                              0.578435  ...
# Bet&Win draw odds                              0.879313  ...
# Bet&Win away odds                              0.985913  ...
# gamebookers home odds                          0.577106  ...
# gamebookers draw odds                          0.857681  ...
# gamebookers away odds                          1.000000  ...
# Interwetten home odds                          0.634519  ...
# Interwetten draw odds                          0.845335  ...
# Interwetten away odds                          0.976471  ...
# Ladbrokes home odds                            0.583221  ...
# Ladbrokes draw odds                            0.847888  ...
# Ladbrokes away odds                            0.981739  ...
# Sportingbet home odds                          0.570210  ...
# Sportingbet draw odds                          0.855003  ...
# Sportingbet away odds                          0.989263  ...
# Will Hill home odds                            0.580222  ...
# Will Hill draw odds                            0.835733  ...
# Will Hill away odds                            0.980841  ...
# Stan James home odds                           0.572709  ...
# Stan James draw odds                           0.855127  ...
# Stan James away odds                           0.991897  ...
# VC Bet home odds                               0.579752  ...
# VC Bet draw odds                               0.854491  ...
# VC Bet away odds                               0.988537  ...
# Betbrain 1X2 bookies                           0.013017  ...
# Betbrain max home odds                         0.545080  ...
# Betbrain average home odds                     0.581087  ...
# Betbrain max draw odds                         0.869694  ...
# Betbrain average draw odds                     0.872864  ...
# Betbrain max away odds                         0.991263  ...
# Betbrain average draw odds.1                   0.996369  ...
# Betbrain over/under bookies                    0.027641  ...
# Betbrain max >2.5                              0.646929  ...
# Betbrain average >2.5                          0.689147  ...
# Betbrain max <2.5                              0.723072  ...
# Betbrain average <2.5                          0.737656  ...
# Betbrain Asian bookies                         0.088237  ...
# Betbrain Asian home handicap                   0.883922  ...
# Betbrain max Asian home odds                   0.121937  ...
# Betbrain average Asian home odds               0.116086  ...
# Betbrain max Asian away odds                   0.125589  ...
# Betbrain average Asian away odds               0.134390  ...
# Div_Cat                                             NaN  ...
# Date_Cat                                       0.062864  ...
# HomeTeam_Cat                                   0.152382  ...
# result_cat                                     0.372692  ...
# AwayTeam_Cat                                   0.060028  ...
#
#                                   Betbrain Asian home handicap  \
# id                                                    0.002888
# Bet365 home odds                                      0.854360
# Bet365 draw odds                                      0.561132
# Bet365 away odds                                      0.870918
# Bet&Win home odds                                     0.848808
# Bet&Win draw odds                                     0.605997
# Bet&Win away odds                                     0.887691
# gamebookers home odds                                 0.851511
# gamebookers draw odds                                 0.570761
# gamebookers away odds                                 0.883922
# Interwetten home odds                                 0.889037
# Interwetten draw odds                                 0.585821
# Interwetten away odds                                 0.901146
# Ladbrokes home odds                                   0.854092
# Ladbrokes draw odds                                   0.554811
# Ladbrokes away odds                                   0.890888
# Sportingbet home odds                                 0.845072
# Sportingbet draw odds                                 0.565884
# Sportingbet away odds                                 0.877897
# Will Hill home odds                                   0.851418
# Will Hill draw odds                                   0.548263
# Will Hill away odds                                   0.890555
# Stan James home odds                                  0.845511
# Stan James draw odds                                  0.580909
# Stan James away odds                                  0.896919
# VC Bet home odds                                      0.855182
# VC Bet draw odds                                      0.565314
# VC Bet away odds                                      0.893000
# Betbrain 1X2 bookies                                  0.010010
# Betbrain max home odds                                0.825183
# Betbrain average home odds                            0.855676
# Betbrain max draw odds                                0.585586
# Betbrain average draw odds                            0.584479
# Betbrain max away odds                                0.868211
# Betbrain average draw odds.1                          0.892529
# Betbrain over/under bookies                           0.026080
# Betbrain max >2.5                                     0.443252
# Betbrain average >2.5                                 0.470556
# Betbrain max <2.5                                     0.500093
# Betbrain average <2.5                                 0.510233
# Betbrain Asian bookies                                0.041133
# Betbrain Asian home handicap                          1.000000
# Betbrain max Asian home odds                          0.054779
# Betbrain average Asian home odds                      0.048633
# Betbrain max Asian away odds                          0.066420
# Betbrain average Asian away odds                      0.064491
# Div_Cat                                                    NaN
# Date_Cat                                              0.038255
# HomeTeam_Cat                                          0.105207
# result_cat                                            0.427120
# AwayTeam_Cat                                          0.145502
#
#                                   Betbrain max Asian home odds  \
# id                                                    0.045503
# Bet365 home odds                                      0.131586
# Bet365 draw odds                                      0.078107
# Bet365 away odds                                      0.124903
# Bet&Win home odds                                     0.123863
# Bet&Win draw odds                                     0.069433
# Bet&Win away odds                                     0.111545
# gamebookers home odds                                 0.123924
# gamebookers draw odds                                 0.100016
# gamebookers away odds                                 0.121937
# Interwetten home odds                                 0.141263
# Interwetten draw odds                                 0.090079
# Interwetten away odds                                 0.145948
# Ladbrokes home odds                                   0.112824
# Ladbrokes draw odds                                   0.119073
# Ladbrokes away odds                                   0.116164
# Sportingbet home odds                                 0.132707
# Sportingbet draw odds                                 0.089618
# Sportingbet away odds                                 0.115044
# Will Hill home odds                                   0.125288
# Will Hill draw odds                                   0.146546
# Will Hill away odds                                   0.119793
# Stan James home odds                                  0.110507
# Stan James draw odds                                  0.074245
# Stan James away odds                                  0.107708
# VC Bet home odds                                      0.124745
# VC Bet draw odds                                      0.094511
# VC Bet away odds                                      0.115468
# Betbrain 1X2 bookies                                  0.050714
# Betbrain max home odds                                0.134766
# Betbrain average home odds                            0.131876
# Betbrain max draw odds                                0.110570
# Betbrain average draw odds                            0.098964
# Betbrain max away odds                                0.134094
# Betbrain average draw odds.1                          0.126686
# Betbrain over/under bookies                           0.047643
# Betbrain max >2.5                                     0.124424
# Betbrain average >2.5                                 0.108644
# Betbrain max <2.5                                     0.112809
# Betbrain average <2.5                                 0.110647
# Betbrain Asian bookies                                0.042961
# Betbrain Asian home handicap                          0.054779
# Betbrain max Asian home odds                          1.000000
# Betbrain average Asian home odds                      0.958510
# Betbrain max Asian away odds                          0.872183
# Betbrain average Asian away odds                      0.966870
# Div_Cat                                                    NaN
# Date_Cat                                              0.016566
# HomeTeam_Cat                                          0.144615
# result_cat                                            0.092330
# AwayTeam_Cat                                          0.063219
#
#                                   Betbrain average Asian home odds  \
# id                                                        0.052911
# Bet365 home odds                                          0.135605
# Bet365 draw odds                                          0.071391
# Bet365 away odds                                          0.120045
# Bet&Win home odds                                         0.127269
# Bet&Win draw odds                                         0.068348
# Bet&Win away odds                                         0.102211
# gamebookers home odds                                     0.127590
# gamebookers draw odds                                     0.090360
# gamebookers away odds                                     0.116086
# Interwetten home odds                                     0.144879
# Interwetten draw odds                                     0.082066
# Interwetten away odds                                     0.133439
# Ladbrokes home odds                                       0.111940
# Ladbrokes draw odds                                       0.114528
# Ladbrokes away odds                                       0.110492
# Sportingbet home odds                                     0.138174
# Sportingbet draw odds                                     0.080352
# Sportingbet away odds                                     0.106078
# Will Hill home odds                                       0.127697
# Will Hill draw odds                                       0.143377
# Will Hill away odds                                       0.110782
# Stan James home odds                                      0.112082
# Stan James draw odds                                      0.068749
# Stan James away odds                                      0.106483
# VC Bet home odds                                          0.126674
# VC Bet draw odds                                          0.086590
# VC Bet away odds                                          0.111894
# Betbrain 1X2 bookies                                      0.026395
# Betbrain max home odds                                    0.139799
# Betbrain average home odds                                0.134829
# Betbrain max draw odds                                    0.100546
# Betbrain average draw odds                                0.087945
# Betbrain max away odds                                    0.128837
# Betbrain average draw odds.1                              0.119650
# Betbrain over/under bookies                               0.018886
# Betbrain max >2.5                                         0.114537
# Betbrain average >2.5                                     0.102495
# Betbrain max <2.5                                         0.098108
# Betbrain average <2.5                                     0.097962
# Betbrain Asian bookies                                    0.001038
# Betbrain Asian home handicap                              0.048633
# Betbrain max Asian home odds                              0.958510
# Betbrain average Asian home odds                          1.000000
# Betbrain max Asian away odds                              0.936029
# Betbrain average Asian away odds                          0.976071
# Div_Cat                                                        NaN
# Date_Cat                                                  0.001861
# HomeTeam_Cat                                              0.146017
# result_cat                                                0.082895
# AwayTeam_Cat                                              0.045787
#
#                                   Betbrain max Asian away odds  \
# id                                                    0.046786
# Bet365 home odds                                      0.141575
# Bet365 draw odds                                      0.078390
# Bet365 away odds                                      0.131100
# Bet&Win home odds                                     0.135171
# Bet&Win draw odds                                     0.065676
# Bet&Win away odds                                     0.108032
# gamebookers home odds                                 0.134062
# gamebookers draw odds                                 0.091229
# gamebookers away odds                                 0.125589
# Interwetten home odds                                 0.150766
# Interwetten draw odds                                 0.089936
# Interwetten away odds                                 0.141006
# Ladbrokes home odds                                   0.123881
# Ladbrokes draw odds                                   0.103580
# Ladbrokes away odds                                   0.121511
# Sportingbet home odds                                 0.142764
# Sportingbet draw odds                                 0.078614
# Sportingbet away odds                                 0.112244
# Will Hill home odds                                   0.134536
# Will Hill draw odds                                   0.130949
# Will Hill away odds                                   0.123794
# Stan James home odds                                  0.121861
# Stan James draw odds                                  0.068030
# Stan James away odds                                  0.121389
# VC Bet home odds                                      0.134338
# VC Bet draw odds                                      0.082430
# VC Bet away odds                                      0.119931
# Betbrain 1X2 bookies                                  0.009462
# Betbrain max home odds                                0.142361
# Betbrain average home odds                            0.142083
# Betbrain max draw odds                                0.107724
# Betbrain average draw odds                            0.087183
# Betbrain max away odds                                0.136950
# Betbrain average draw odds.1                          0.130891
# Betbrain over/under bookies                           0.021671
# Betbrain max >2.5                                     0.089402
# Betbrain average >2.5                                 0.091859
# Betbrain max <2.5                                     0.087223
# Betbrain average <2.5                                 0.082919
# Betbrain Asian bookies                                0.058448
# Betbrain Asian home handicap                          0.066420
# Betbrain max Asian home odds                          0.872183
# Betbrain average Asian home odds                      0.936029
# Betbrain max Asian away odds                          1.000000
# Betbrain average Asian away odds                      0.935553
# Div_Cat                                                    NaN
# Date_Cat                                              0.003510
# HomeTeam_Cat                                          0.120468
# result_cat                                            0.102839
# AwayTeam_Cat                                          0.041215
#
#                                   Betbrain average Asian away odds  Div_Cat  \
# id                                                        0.045581      NaN
# Bet365 home odds                                          0.144956      NaN
# Bet365 draw odds                                          0.086809      NaN
# Bet365 away odds                                          0.138792      NaN
# Bet&Win home odds                                         0.139479      NaN
# Bet&Win draw odds                                         0.079609      NaN
# Bet&Win away odds                                         0.119770      NaN
# gamebookers home odds                                     0.137856      NaN
# gamebookers draw odds                                     0.107546      NaN
# gamebookers away odds                                     0.134390      NaN
# Interwetten home odds                                     0.155508      NaN
# Interwetten draw odds                                     0.098131      NaN
# Interwetten away odds                                     0.155495      NaN
# Ladbrokes home odds                                       0.124453      NaN
# Ladbrokes draw odds                                       0.127959      NaN
# Ladbrokes away odds                                       0.124678      NaN
# Sportingbet home odds                                     0.146322      NaN
# Sportingbet draw odds                                     0.093563      NaN
# Sportingbet away odds                                     0.125576      NaN
# Will Hill home odds                                       0.137752      NaN
# Will Hill draw odds                                       0.152193      NaN
# Will Hill away odds                                       0.129861      NaN
# Stan James home odds                                      0.124875      NaN
# Stan James draw odds                                      0.080863      NaN
# Stan James away odds                                      0.123118      NaN
# VC Bet home odds                                          0.137596      NaN
# VC Bet draw odds                                          0.098266      NaN
# VC Bet away odds                                          0.125554      NaN
# Betbrain 1X2 bookies                                      0.015951      NaN
# Betbrain max home odds                                    0.143851      NaN
# Betbrain average home odds                                0.144584      NaN
# Betbrain max draw odds                                    0.120541      NaN
# Betbrain average draw odds                                0.104187      NaN
# Betbrain max away odds                                    0.145480      NaN
# Betbrain average draw odds.1                              0.138060      NaN
# Betbrain over/under bookies                               0.005787      NaN
# Betbrain max >2.5                                         0.112533      NaN
# Betbrain average >2.5                                     0.107635      NaN
# Betbrain max <2.5                                         0.110855      NaN
# Betbrain average <2.5                                     0.106515      NaN
# Betbrain Asian bookies                                    0.005330      NaN
# Betbrain Asian home handicap                              0.064491      NaN
# Betbrain max Asian home odds                              0.966870      NaN
# Betbrain average Asian home odds                          0.976071      NaN
# Betbrain max Asian away odds                              0.935553      NaN
# Betbrain average Asian away odds                          1.000000      NaN
# Div_Cat                                                        NaN      NaN
# Date_Cat                                                  0.010629      NaN
# HomeTeam_Cat                                              0.141623      NaN
# result_cat                                                0.097028      NaN
# AwayTeam_Cat                                              0.048005      NaN
#
#                                   Date_Cat  HomeTeam_Cat  result_cat  \
# id                                0.231710      0.062827    0.093876
# Bet365 home odds                  0.064319      0.067192    0.361026
# Bet365 draw odds                  0.029037      0.177137    0.245922
# Bet365 away odds                  0.051488      0.150711    0.368675
# Bet&Win home odds                 0.075872      0.046601    0.355854
# Bet&Win draw odds                 0.054619      0.176119    0.248575
# Bet&Win away odds                 0.061809      0.154123    0.373967
# gamebookers home odds             0.063218      0.058007    0.365681
# gamebookers draw odds             0.036408      0.183071    0.241779
# gamebookers away odds             0.062864      0.152382    0.372692
# Interwetten home odds             0.064014      0.060602    0.374932
# Interwetten draw odds             0.028316      0.181975    0.262286
# Interwetten away odds             0.042120      0.160172    0.386434
# Ladbrokes home odds               0.061723      0.045576    0.361882
# Ladbrokes draw odds               0.020869      0.164173    0.210883
# Ladbrokes away odds               0.036710      0.136372    0.378551
# Sportingbet home odds             0.055785      0.061690    0.354842
# Sportingbet draw odds             0.013170      0.179237    0.227459
# Sportingbet away odds             0.064775      0.151697    0.367086
# Will Hill home odds               0.060156      0.050552    0.366958
# Will Hill draw odds               0.009594      0.199804    0.217216
# Will Hill away odds               0.051636      0.139303    0.390083
# Stan James home odds              0.068230      0.041466    0.347955
# Stan James draw odds              0.027726      0.189200    0.255150
# Stan James away odds              0.054452      0.140845    0.378937
# VC Bet home odds                  0.059851      0.048799    0.361772
# VC Bet draw odds                  0.028443      0.178172    0.240081
# VC Bet away odds                  0.047228      0.130958    0.373018
# Betbrain 1X2 bookies              0.275521      0.013019    0.025649
# Betbrain max home odds            0.048244      0.055045    0.356248
# Betbrain average home odds        0.062221      0.056259    0.364733
# Betbrain max draw odds            0.043305      0.164930    0.240894
# Betbrain average draw odds        0.031335      0.179455    0.239920
# Betbrain max away odds            0.065387      0.152021    0.369955
# Betbrain average draw odds.1      0.053955      0.151607    0.380638
# Betbrain over/under bookies       0.225134      0.008659    0.006475
# Betbrain max >2.5                 0.030439      0.179924    0.125542
# Betbrain average >2.5             0.021737      0.185776    0.115177
# Betbrain max <2.5                 0.006601      0.201014    0.147049
# Betbrain average <2.5             0.011049      0.199980    0.153435
# Betbrain Asian bookies            0.299957      0.014367    0.128893
# Betbrain Asian home handicap      0.038255      0.105207    0.427120
# Betbrain max Asian home odds      0.016566      0.144615    0.092330
# Betbrain average Asian home odds  0.001861      0.146017    0.082895
# Betbrain max Asian away odds      0.003510      0.120468    0.102839
# Betbrain average Asian away odds  0.010629      0.141623    0.097028
# Div_Cat                                NaN           NaN         NaN
# Date_Cat                          1.000000      0.076932    0.061661
# HomeTeam_Cat                      0.076932      1.000000    0.144005
# result_cat                        0.061661      0.144005    1.000000
# AwayTeam_Cat                      0.006958      0.023449    0.062998
#
#                                   AwayTeam_Cat
# id                                    0.003878
# Bet365 home odds                      0.191977
# Bet365 draw odds                      0.033212
# Bet365 away odds                      0.058628
# Bet&Win home odds                     0.191561
# Bet&Win draw odds                     0.026832
# Bet&Win away odds                     0.050371
# gamebookers home odds                 0.186958
# gamebookers draw odds                 0.033677
# gamebookers away odds                 0.060028
# Interwetten home odds                 0.193497
# Interwetten draw odds                 0.032785
# Interwetten away odds                 0.081053
# Ladbrokes home odds                   0.167065
# Ladbrokes draw odds                   0.029204
# Ladbrokes away odds                   0.063464
# Sportingbet home odds                 0.191431
# Sportingbet draw odds                 0.031941
# Sportingbet away odds                 0.056014
# Will Hill home odds                   0.175472
# Will Hill draw odds                   0.059202
# Will Hill away odds                   0.062904
# Stan James home odds                  0.197277
# Stan James draw odds                  0.025036
# Stan James away odds                  0.070749
# VC Bet home odds                      0.184068
# VC Bet draw odds                      0.035026
# VC Bet away odds                      0.076244
# Betbrain 1X2 bookies                  0.034605
# Betbrain max home odds                0.182211
# Betbrain average home odds            0.186951
# Betbrain max draw odds                0.008172
# Betbrain average draw odds            0.034491
# Betbrain max away odds                0.052834
# Betbrain average draw odds.1          0.063995
# Betbrain over/under bookies           0.056090
# Betbrain max >2.5                     0.046432
# Betbrain average >2.5                 0.056591
# Betbrain max <2.5                     0.040276
# Betbrain average <2.5                 0.048986
# Betbrain Asian bookies                0.057275
# Betbrain Asian home handicap          0.145502
# Betbrain max Asian home odds          0.063219
# Betbrain average Asian home odds      0.045787
# Betbrain max Asian away odds          0.041215
# Betbrain average Asian away odds      0.048005
# Div_Cat                                    NaN
# Date_Cat                              0.006958
# HomeTeam_Cat                          0.023449
# result_cat                            0.062998
# AwayTeam_Cat                          1.000000
#
# [51 rows x 51 columns]

# %%
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(bool))
print(upper_tri)
# Out:
#                                   id  Bet365 home odds  Bet365 draw odds  \
# id                               NaN           0.03555          0.124160
# Bet365 home odds                 NaN               NaN          0.132768
# Bet365 draw odds                 NaN               NaN               NaN
# Bet365 away odds                 NaN               NaN               NaN
# Bet&Win home odds                NaN               NaN               NaN
# Bet&Win draw odds                NaN               NaN               NaN
# Bet&Win away odds                NaN               NaN               NaN
# gamebookers home odds            NaN               NaN               NaN
# gamebookers draw odds            NaN               NaN               NaN
# gamebookers away odds            NaN               NaN               NaN
# Interwetten home odds            NaN               NaN               NaN
# Interwetten draw odds            NaN               NaN               NaN
# Interwetten away odds            NaN               NaN               NaN
# Ladbrokes home odds              NaN               NaN               NaN
# Ladbrokes draw odds              NaN               NaN               NaN
# Ladbrokes away odds              NaN               NaN               NaN
# Sportingbet home odds            NaN               NaN               NaN
# Sportingbet draw odds            NaN               NaN               NaN
# Sportingbet away odds            NaN               NaN               NaN
# Will Hill home odds              NaN               NaN               NaN
# Will Hill draw odds              NaN               NaN               NaN
# Will Hill away odds              NaN               NaN               NaN
# Stan James home odds             NaN               NaN               NaN
# Stan James draw odds             NaN               NaN               NaN
# Stan James away odds             NaN               NaN               NaN
# VC Bet home odds                 NaN               NaN               NaN
# VC Bet draw odds                 NaN               NaN               NaN
# VC Bet away odds                 NaN               NaN               NaN
# Betbrain 1X2 bookies             NaN               NaN               NaN
# Betbrain max home odds           NaN               NaN               NaN
# Betbrain average home odds       NaN               NaN               NaN
# Betbrain max draw odds           NaN               NaN               NaN
# Betbrain average draw odds       NaN               NaN               NaN
# Betbrain max away odds           NaN               NaN               NaN
# Betbrain average draw odds.1     NaN               NaN               NaN
# Betbrain over/under bookies      NaN               NaN               NaN
# Betbrain max >2.5                NaN               NaN               NaN
# Betbrain average >2.5            NaN               NaN               NaN
# Betbrain max <2.5                NaN               NaN               NaN
# Betbrain average <2.5            NaN               NaN               NaN
# Betbrain Asian bookies           NaN               NaN               NaN
# Betbrain Asian home handicap     NaN               NaN               NaN
# Betbrain max Asian home odds     NaN               NaN               NaN
# Betbrain average Asian home odds NaN               NaN               NaN
# Betbrain max Asian away odds     NaN               NaN               NaN
# Betbrain average Asian away odds NaN               NaN               NaN
# Div_Cat                          NaN               NaN               NaN
# Date_Cat                         NaN               NaN               NaN
# HomeTeam_Cat                     NaN               NaN               NaN
# result_cat                       NaN               NaN               NaN
# AwayTeam_Cat                     NaN               NaN               NaN
#
#                                   Bet365 away odds  Bet&Win home odds  \
# id                                        0.019072           0.059714
# Bet365 home odds                          0.566687           0.986309
# Bet365 draw odds                          0.842207           0.128503
# Bet365 away odds                               NaN           0.563396
# Bet&Win home odds                              NaN                NaN
# Bet&Win draw odds                              NaN                NaN
# Bet&Win away odds                              NaN                NaN
# gamebookers home odds                          NaN                NaN
# gamebookers draw odds                          NaN                NaN
# gamebookers away odds                          NaN                NaN
# Interwetten home odds                          NaN                NaN
# Interwetten draw odds                          NaN                NaN
# Interwetten away odds                          NaN                NaN
# Ladbrokes home odds                            NaN                NaN
# Ladbrokes draw odds                            NaN                NaN
# Ladbrokes away odds                            NaN                NaN
# Sportingbet home odds                          NaN                NaN
# Sportingbet draw odds                          NaN                NaN
# Sportingbet away odds                          NaN                NaN
# Will Hill home odds                            NaN                NaN
# Will Hill draw odds                            NaN                NaN
# Will Hill away odds                            NaN                NaN
# Stan James home odds                           NaN                NaN
# Stan James draw odds                           NaN                NaN
# Stan James away odds                           NaN                NaN
# VC Bet home odds                               NaN                NaN
# VC Bet draw odds                               NaN                NaN
# VC Bet away odds                               NaN                NaN
# Betbrain 1X2 bookies                           NaN                NaN
# Betbrain max home odds                         NaN                NaN
# Betbrain average home odds                     NaN                NaN
# Betbrain max draw odds                         NaN                NaN
# Betbrain average draw odds                     NaN                NaN
# Betbrain max away odds                         NaN                NaN
# Betbrain average draw odds.1                   NaN                NaN
# Betbrain over/under bookies                    NaN                NaN
# Betbrain max >2.5                              NaN                NaN
# Betbrain average >2.5                          NaN                NaN
# Betbrain max <2.5                              NaN                NaN
# Betbrain average <2.5                          NaN                NaN
# Betbrain Asian bookies                         NaN                NaN
# Betbrain Asian home handicap                   NaN                NaN
# Betbrain max Asian home odds                   NaN                NaN
# Betbrain average Asian home odds               NaN                NaN
# Betbrain max Asian away odds                   NaN                NaN
# Betbrain average Asian away odds               NaN                NaN
# Div_Cat                                        NaN                NaN
# Date_Cat                                       NaN                NaN
# HomeTeam_Cat                                   NaN                NaN
# result_cat                                     NaN                NaN
# AwayTeam_Cat                                   NaN                NaN
#
#                                   Bet&Win draw odds  Bet&Win away odds  \
# id                                         0.028041           0.023659
# Bet365 home odds                           0.186237           0.593774
# Bet365 draw odds                           0.954753           0.836777
# Bet365 away odds                           0.877345           0.973532
# Bet&Win home odds                          0.185629           0.595333
# Bet&Win draw odds                               NaN           0.870202
# Bet&Win away odds                               NaN                NaN
# gamebookers home odds                           NaN                NaN
# gamebookers draw odds                           NaN                NaN
# gamebookers away odds                           NaN                NaN
# Interwetten home odds                           NaN                NaN
# Interwetten draw odds                           NaN                NaN
# Interwetten away odds                           NaN                NaN
# Ladbrokes home odds                             NaN                NaN
# Ladbrokes draw odds                             NaN                NaN
# Ladbrokes away odds                             NaN                NaN
# Sportingbet home odds                           NaN                NaN
# Sportingbet draw odds                           NaN                NaN
# Sportingbet away odds                           NaN                NaN
# Will Hill home odds                             NaN                NaN
# Will Hill draw odds                             NaN                NaN
# Will Hill away odds                             NaN                NaN
# Stan James home odds                            NaN                NaN
# Stan James draw odds                            NaN                NaN
# Stan James away odds                            NaN                NaN
# VC Bet home odds                                NaN                NaN
# VC Bet draw odds                                NaN                NaN
# VC Bet away odds                                NaN                NaN
# Betbrain 1X2 bookies                            NaN                NaN
# Betbrain max home odds                          NaN                NaN
# Betbrain average home odds                      NaN                NaN
# Betbrain max draw odds                          NaN                NaN
# Betbrain average draw odds                      NaN                NaN
# Betbrain max away odds                          NaN                NaN
# Betbrain average draw odds.1                    NaN                NaN
# Betbrain over/under bookies                     NaN                NaN
# Betbrain max >2.5                               NaN                NaN
# Betbrain average >2.5                           NaN                NaN
# Betbrain max <2.5                               NaN                NaN
# Betbrain average <2.5                           NaN                NaN
# Betbrain Asian bookies                          NaN                NaN
# Betbrain Asian home handicap                    NaN                NaN
# Betbrain max Asian home odds                    NaN                NaN
# Betbrain average Asian home odds                NaN                NaN
# Betbrain max Asian away odds                    NaN                NaN
# Betbrain average Asian away odds                NaN                NaN
# Div_Cat                                         NaN                NaN
# Date_Cat                                        NaN                NaN
# HomeTeam_Cat                                    NaN                NaN
# result_cat                                      NaN                NaN
# AwayTeam_Cat                                    NaN                NaN
#
#                                   gamebookers home odds  \
# id                                             0.035367
# Bet365 home odds                               0.993317
# Bet365 draw odds                               0.128251
# Bet365 away odds                               0.561625
# Bet&Win home odds                              0.986333
# Bet&Win draw odds                              0.183667
# Bet&Win away odds                              0.589892
# gamebookers home odds                               NaN
# gamebookers draw odds                               NaN
# gamebookers away odds                               NaN
# Interwetten home odds                               NaN
# Interwetten draw odds                               NaN
# Interwetten away odds                               NaN
# Ladbrokes home odds                                 NaN
# Ladbrokes draw odds                                 NaN
# Ladbrokes away odds                                 NaN
# Sportingbet home odds                               NaN
# Sportingbet draw odds                               NaN
# Sportingbet away odds                               NaN
# Will Hill home odds                                 NaN
# Will Hill draw odds                                 NaN
# Will Hill away odds                                 NaN
# Stan James home odds                                NaN
# Stan James draw odds                                NaN
# Stan James away odds                                NaN
# VC Bet home odds                                    NaN
# VC Bet draw odds                                    NaN
# VC Bet away odds                                    NaN
# Betbrain 1X2 bookies                                NaN
# Betbrain max home odds                              NaN
# Betbrain average home odds                          NaN
# Betbrain max draw odds                              NaN
# Betbrain average draw odds                          NaN
# Betbrain max away odds                              NaN
# Betbrain average draw odds.1                        NaN
# Betbrain over/under bookies                         NaN
# Betbrain max >2.5                                   NaN
# Betbrain average >2.5                               NaN
# Betbrain max <2.5                                   NaN
# Betbrain average <2.5                               NaN
# Betbrain Asian bookies                              NaN
# Betbrain Asian home handicap                        NaN
# Betbrain max Asian home odds                        NaN
# Betbrain average Asian home odds                    NaN
# Betbrain max Asian away odds                        NaN
# Betbrain average Asian away odds                    NaN
# Div_Cat                                             NaN
# Date_Cat                                            NaN
# HomeTeam_Cat                                        NaN
# result_cat                                          NaN
# AwayTeam_Cat                                        NaN
#
#                                   gamebookers draw odds  \
# id                                             0.093806
# Bet365 home odds                               0.141060
# Bet365 draw odds                               0.982339
# Bet365 away odds                               0.860857
# Bet&Win home odds                              0.140901
# Bet&Win draw odds                              0.971654
# Bet&Win away odds                              0.846627
# gamebookers home odds                          0.139802
# gamebookers draw odds                               NaN
# gamebookers away odds                               NaN
# Interwetten home odds                               NaN
# Interwetten draw odds                               NaN
# Interwetten away odds                               NaN
# Ladbrokes home odds                                 NaN
# Ladbrokes draw odds                                 NaN
# Ladbrokes away odds                                 NaN
# Sportingbet home odds                               NaN
# Sportingbet draw odds                               NaN
# Sportingbet away odds                               NaN
# Will Hill home odds                                 NaN
# Will Hill draw odds                                 NaN
# Will Hill away odds                                 NaN
# Stan James home odds                                NaN
# Stan James draw odds                                NaN
# Stan James away odds                                NaN
# VC Bet home odds                                    NaN
# VC Bet draw odds                                    NaN
# VC Bet away odds                                    NaN
# Betbrain 1X2 bookies                                NaN
# Betbrain max home odds                              NaN
# Betbrain average home odds                          NaN
# Betbrain max draw odds                              NaN
# Betbrain average draw odds                          NaN
# Betbrain max away odds                              NaN
# Betbrain average draw odds.1                        NaN
# Betbrain over/under bookies                         NaN
# Betbrain max >2.5                                   NaN
# Betbrain average >2.5                               NaN
# Betbrain max <2.5                                   NaN
# Betbrain average <2.5                               NaN
# Betbrain Asian bookies                              NaN
# Betbrain Asian home handicap                        NaN
# Betbrain max Asian home odds                        NaN
# Betbrain average Asian home odds                    NaN
# Betbrain max Asian away odds                        NaN
# Betbrain average Asian away odds                    NaN
# Div_Cat                                             NaN
# Date_Cat                                            NaN
# HomeTeam_Cat                                        NaN
# result_cat                                          NaN
# AwayTeam_Cat                                        NaN
#
#                                   gamebookers away odds  ...  \
# id                                             0.020949  ...
# Bet365 home odds                               0.580572  ...
# Bet365 draw odds                               0.844580  ...
# Bet365 away odds                               0.983955  ...
# Bet&Win home odds                              0.578435  ...
# Bet&Win draw odds                              0.879313  ...
# Bet&Win away odds                              0.985913  ...
# gamebookers home odds                          0.577106  ...
# gamebookers draw odds                          0.857681  ...
# gamebookers away odds                               NaN  ...
# Interwetten home odds                               NaN  ...
# Interwetten draw odds                               NaN  ...
# Interwetten away odds                               NaN  ...
# Ladbrokes home odds                                 NaN  ...
# Ladbrokes draw odds                                 NaN  ...
# Ladbrokes away odds                                 NaN  ...
# Sportingbet home odds                               NaN  ...
# Sportingbet draw odds                               NaN  ...
# Sportingbet away odds                               NaN  ...
# Will Hill home odds                                 NaN  ...
# Will Hill draw odds                                 NaN  ...
# Will Hill away odds                                 NaN  ...
# Stan James home odds                                NaN  ...
# Stan James draw odds                                NaN  ...
# Stan James away odds                                NaN  ...
# VC Bet home odds                                    NaN  ...
# VC Bet draw odds                                    NaN  ...
# VC Bet away odds                                    NaN  ...
# Betbrain 1X2 bookies                                NaN  ...
# Betbrain max home odds                              NaN  ...
# Betbrain average home odds                          NaN  ...
# Betbrain max draw odds                              NaN  ...
# Betbrain average draw odds                          NaN  ...
# Betbrain max away odds                              NaN  ...
# Betbrain average draw odds.1                        NaN  ...
# Betbrain over/under bookies                         NaN  ...
# Betbrain max >2.5                                   NaN  ...
# Betbrain average >2.5                               NaN  ...
# Betbrain max <2.5                                   NaN  ...
# Betbrain average <2.5                               NaN  ...
# Betbrain Asian bookies                              NaN  ...
# Betbrain Asian home handicap                        NaN  ...
# Betbrain max Asian home odds                        NaN  ...
# Betbrain average Asian home odds                    NaN  ...
# Betbrain max Asian away odds                        NaN  ...
# Betbrain average Asian away odds                    NaN  ...
# Div_Cat                                             NaN  ...
# Date_Cat                                            NaN  ...
# HomeTeam_Cat                                        NaN  ...
# result_cat                                          NaN  ...
# AwayTeam_Cat                                        NaN  ...
#
#                                   Betbrain Asian home handicap  \
# id                                                    0.002888
# Bet365 home odds                                      0.854360
# Bet365 draw odds                                      0.561132
# Bet365 away odds                                      0.870918
# Bet&Win home odds                                     0.848808
# Bet&Win draw odds                                     0.605997
# Bet&Win away odds                                     0.887691
# gamebookers home odds                                 0.851511
# gamebookers draw odds                                 0.570761
# gamebookers away odds                                 0.883922
# Interwetten home odds                                 0.889037
# Interwetten draw odds                                 0.585821
# Interwetten away odds                                 0.901146
# Ladbrokes home odds                                   0.854092
# Ladbrokes draw odds                                   0.554811
# Ladbrokes away odds                                   0.890888
# Sportingbet home odds                                 0.845072
# Sportingbet draw odds                                 0.565884
# Sportingbet away odds                                 0.877897
# Will Hill home odds                                   0.851418
# Will Hill draw odds                                   0.548263
# Will Hill away odds                                   0.890555
# Stan James home odds                                  0.845511
# Stan James draw odds                                  0.580909
# Stan James away odds                                  0.896919
# VC Bet home odds                                      0.855182
# VC Bet draw odds                                      0.565314
# VC Bet away odds                                      0.893000
# Betbrain 1X2 bookies                                  0.010010
# Betbrain max home odds                                0.825183
# Betbrain average home odds                            0.855676
# Betbrain max draw odds                                0.585586
# Betbrain average draw odds                            0.584479
# Betbrain max away odds                                0.868211
# Betbrain average draw odds.1                          0.892529
# Betbrain over/under bookies                           0.026080
# Betbrain max >2.5                                     0.443252
# Betbrain average >2.5                                 0.470556
# Betbrain max <2.5                                     0.500093
# Betbrain average <2.5                                 0.510233
# Betbrain Asian bookies                                0.041133
# Betbrain Asian home handicap                               NaN
# Betbrain max Asian home odds                               NaN
# Betbrain average Asian home odds                           NaN
# Betbrain max Asian away odds                               NaN
# Betbrain average Asian away odds                           NaN
# Div_Cat                                                    NaN
# Date_Cat                                                   NaN
# HomeTeam_Cat                                               NaN
# result_cat                                                 NaN
# AwayTeam_Cat                                               NaN
#
#                                   Betbrain max Asian home odds  \
# id                                                    0.045503
# Bet365 home odds                                      0.131586
# Bet365 draw odds                                      0.078107
# Bet365 away odds                                      0.124903
# Bet&Win home odds                                     0.123863
# Bet&Win draw odds                                     0.069433
# Bet&Win away odds                                     0.111545
# gamebookers home odds                                 0.123924
# gamebookers draw odds                                 0.100016
# gamebookers away odds                                 0.121937
# Interwetten home odds                                 0.141263
# Interwetten draw odds                                 0.090079
# Interwetten away odds                                 0.145948
# Ladbrokes home odds                                   0.112824
# Ladbrokes draw odds                                   0.119073
# Ladbrokes away odds                                   0.116164
# Sportingbet home odds                                 0.132707
# Sportingbet draw odds                                 0.089618
# Sportingbet away odds                                 0.115044
# Will Hill home odds                                   0.125288
# Will Hill draw odds                                   0.146546
# Will Hill away odds                                   0.119793
# Stan James home odds                                  0.110507
# Stan James draw odds                                  0.074245
# Stan James away odds                                  0.107708
# VC Bet home odds                                      0.124745
# VC Bet draw odds                                      0.094511
# VC Bet away odds                                      0.115468
# Betbrain 1X2 bookies                                  0.050714
# Betbrain max home odds                                0.134766
# Betbrain average home odds                            0.131876
# Betbrain max draw odds                                0.110570
# Betbrain average draw odds                            0.098964
# Betbrain max away odds                                0.134094
# Betbrain average draw odds.1                          0.126686
# Betbrain over/under bookies                           0.047643
# Betbrain max >2.5                                     0.124424
# Betbrain average >2.5                                 0.108644
# Betbrain max <2.5                                     0.112809
# Betbrain average <2.5                                 0.110647
# Betbrain Asian bookies                                0.042961
# Betbrain Asian home handicap                          0.054779
# Betbrain max Asian home odds                               NaN
# Betbrain average Asian home odds                           NaN
# Betbrain max Asian away odds                               NaN
# Betbrain average Asian away odds                           NaN
# Div_Cat                                                    NaN
# Date_Cat                                                   NaN
# HomeTeam_Cat                                               NaN
# result_cat                                                 NaN
# AwayTeam_Cat                                               NaN
#
#                                   Betbrain average Asian home odds  \
# id                                                        0.052911
# Bet365 home odds                                          0.135605
# Bet365 draw odds                                          0.071391
# Bet365 away odds                                          0.120045
# Bet&Win home odds                                         0.127269
# Bet&Win draw odds                                         0.068348
# Bet&Win away odds                                         0.102211
# gamebookers home odds                                     0.127590
# gamebookers draw odds                                     0.090360
# gamebookers away odds                                     0.116086
# Interwetten home odds                                     0.144879
# Interwetten draw odds                                     0.082066
# Interwetten away odds                                     0.133439
# Ladbrokes home odds                                       0.111940
# Ladbrokes draw odds                                       0.114528
# Ladbrokes away odds                                       0.110492
# Sportingbet home odds                                     0.138174
# Sportingbet draw odds                                     0.080352
# Sportingbet away odds                                     0.106078
# Will Hill home odds                                       0.127697
# Will Hill draw odds                                       0.143377
# Will Hill away odds                                       0.110782
# Stan James home odds                                      0.112082
# Stan James draw odds                                      0.068749
# Stan James away odds                                      0.106483
# VC Bet home odds                                          0.126674
# VC Bet draw odds                                          0.086590
# VC Bet away odds                                          0.111894
# Betbrain 1X2 bookies                                      0.026395
# Betbrain max home odds                                    0.139799
# Betbrain average home odds                                0.134829
# Betbrain max draw odds                                    0.100546
# Betbrain average draw odds                                0.087945
# Betbrain max away odds                                    0.128837
# Betbrain average draw odds.1                              0.119650
# Betbrain over/under bookies                               0.018886
# Betbrain max >2.5                                         0.114537
# Betbrain average >2.5                                     0.102495
# Betbrain max <2.5                                         0.098108
# Betbrain average <2.5                                     0.097962
# Betbrain Asian bookies                                    0.001038
# Betbrain Asian home handicap                              0.048633
# Betbrain max Asian home odds                              0.958510
# Betbrain average Asian home odds                               NaN
# Betbrain max Asian away odds                                   NaN
# Betbrain average Asian away odds                               NaN
# Div_Cat                                                        NaN
# Date_Cat                                                       NaN
# HomeTeam_Cat                                                   NaN
# result_cat                                                     NaN
# AwayTeam_Cat                                                   NaN
#
#                                   Betbrain max Asian away odds  \
# id                                                    0.046786
# Bet365 home odds                                      0.141575
# Bet365 draw odds                                      0.078390
# Bet365 away odds                                      0.131100
# Bet&Win home odds                                     0.135171
# Bet&Win draw odds                                     0.065676
# Bet&Win away odds                                     0.108032
# gamebookers home odds                                 0.134062
# gamebookers draw odds                                 0.091229
# gamebookers away odds                                 0.125589
# Interwetten home odds                                 0.150766
# Interwetten draw odds                                 0.089936
# Interwetten away odds                                 0.141006
# Ladbrokes home odds                                   0.123881
# Ladbrokes draw odds                                   0.103580
# Ladbrokes away odds                                   0.121511
# Sportingbet home odds                                 0.142764
# Sportingbet draw odds                                 0.078614
# Sportingbet away odds                                 0.112244
# Will Hill home odds                                   0.134536
# Will Hill draw odds                                   0.130949
# Will Hill away odds                                   0.123794
# Stan James home odds                                  0.121861
# Stan James draw odds                                  0.068030
# Stan James away odds                                  0.121389
# VC Bet home odds                                      0.134338
# VC Bet draw odds                                      0.082430
# VC Bet away odds                                      0.119931
# Betbrain 1X2 bookies                                  0.009462
# Betbrain max home odds                                0.142361
# Betbrain average home odds                            0.142083
# Betbrain max draw odds                                0.107724
# Betbrain average draw odds                            0.087183
# Betbrain max away odds                                0.136950
# Betbrain average draw odds.1                          0.130891
# Betbrain over/under bookies                           0.021671
# Betbrain max >2.5                                     0.089402
# Betbrain average >2.5                                 0.091859
# Betbrain max <2.5                                     0.087223
# Betbrain average <2.5                                 0.082919
# Betbrain Asian bookies                                0.058448
# Betbrain Asian home handicap                          0.066420
# Betbrain max Asian home odds                          0.872183
# Betbrain average Asian home odds                      0.936029
# Betbrain max Asian away odds                               NaN
# Betbrain average Asian away odds                           NaN
# Div_Cat                                                    NaN
# Date_Cat                                                   NaN
# HomeTeam_Cat                                               NaN
# result_cat                                                 NaN
# AwayTeam_Cat                                               NaN
#
#                                   Betbrain average Asian away odds  Div_Cat  \
# id                                                        0.045581      NaN
# Bet365 home odds                                          0.144956      NaN
# Bet365 draw odds                                          0.086809      NaN
# Bet365 away odds                                          0.138792      NaN
# Bet&Win home odds                                         0.139479      NaN
# Bet&Win draw odds                                         0.079609      NaN
# Bet&Win away odds                                         0.119770      NaN
# gamebookers home odds                                     0.137856      NaN
# gamebookers draw odds                                     0.107546      NaN
# gamebookers away odds                                     0.134390      NaN
# Interwetten home odds                                     0.155508      NaN
# Interwetten draw odds                                     0.098131      NaN
# Interwetten away odds                                     0.155495      NaN
# Ladbrokes home odds                                       0.124453      NaN
# Ladbrokes draw odds                                       0.127959      NaN
# Ladbrokes away odds                                       0.124678      NaN
# Sportingbet home odds                                     0.146322      NaN
# Sportingbet draw odds                                     0.093563      NaN
# Sportingbet away odds                                     0.125576      NaN
# Will Hill home odds                                       0.137752      NaN
# Will Hill draw odds                                       0.152193      NaN
# Will Hill away odds                                       0.129861      NaN
# Stan James home odds                                      0.124875      NaN
# Stan James draw odds                                      0.080863      NaN
# Stan James away odds                                      0.123118      NaN
# VC Bet home odds                                          0.137596      NaN
# VC Bet draw odds                                          0.098266      NaN
# VC Bet away odds                                          0.125554      NaN
# Betbrain 1X2 bookies                                      0.015951      NaN
# Betbrain max home odds                                    0.143851      NaN
# Betbrain average home odds                                0.144584      NaN
# Betbrain max draw odds                                    0.120541      NaN
# Betbrain average draw odds                                0.104187      NaN
# Betbrain max away odds                                    0.145480      NaN
# Betbrain average draw odds.1                              0.138060      NaN
# Betbrain over/under bookies                               0.005787      NaN
# Betbrain max >2.5                                         0.112533      NaN
# Betbrain average >2.5                                     0.107635      NaN
# Betbrain max <2.5                                         0.110855      NaN
# Betbrain average <2.5                                     0.106515      NaN
# Betbrain Asian bookies                                    0.005330      NaN
# Betbrain Asian home handicap                              0.064491      NaN
# Betbrain max Asian home odds                              0.966870      NaN
# Betbrain average Asian home odds                          0.976071      NaN
# Betbrain max Asian away odds                              0.935553      NaN
# Betbrain average Asian away odds                               NaN      NaN
# Div_Cat                                                        NaN      NaN
# Date_Cat                                                       NaN      NaN
# HomeTeam_Cat                                                   NaN      NaN
# result_cat                                                     NaN      NaN
# AwayTeam_Cat                                                   NaN      NaN
#
#                                   Date_Cat  HomeTeam_Cat  result_cat  \
# id                                0.231710      0.062827    0.093876
# Bet365 home odds                  0.064319      0.067192    0.361026
# Bet365 draw odds                  0.029037      0.177137    0.245922
# Bet365 away odds                  0.051488      0.150711    0.368675
# Bet&Win home odds                 0.075872      0.046601    0.355854
# Bet&Win draw odds                 0.054619      0.176119    0.248575
# Bet&Win away odds                 0.061809      0.154123    0.373967
# gamebookers home odds             0.063218      0.058007    0.365681
# gamebookers draw odds             0.036408      0.183071    0.241779
# gamebookers away odds             0.062864      0.152382    0.372692
# Interwetten home odds             0.064014      0.060602    0.374932
# Interwetten draw odds             0.028316      0.181975    0.262286
# Interwetten away odds             0.042120      0.160172    0.386434
# Ladbrokes home odds               0.061723      0.045576    0.361882
# Ladbrokes draw odds               0.020869      0.164173    0.210883
# Ladbrokes away odds               0.036710      0.136372    0.378551
# Sportingbet home odds             0.055785      0.061690    0.354842
# Sportingbet draw odds             0.013170      0.179237    0.227459
# Sportingbet away odds             0.064775      0.151697    0.367086
# Will Hill home odds               0.060156      0.050552    0.366958
# Will Hill draw odds               0.009594      0.199804    0.217216
# Will Hill away odds               0.051636      0.139303    0.390083
# Stan James home odds              0.068230      0.041466    0.347955
# Stan James draw odds              0.027726      0.189200    0.255150
# Stan James away odds              0.054452      0.140845    0.378937
# VC Bet home odds                  0.059851      0.048799    0.361772
# VC Bet draw odds                  0.028443      0.178172    0.240081
# VC Bet away odds                  0.047228      0.130958    0.373018
# Betbrain 1X2 bookies              0.275521      0.013019    0.025649
# Betbrain max home odds            0.048244      0.055045    0.356248
# Betbrain average home odds        0.062221      0.056259    0.364733
# Betbrain max draw odds            0.043305      0.164930    0.240894
# Betbrain average draw odds        0.031335      0.179455    0.239920
# Betbrain max away odds            0.065387      0.152021    0.369955
# Betbrain average draw odds.1      0.053955      0.151607    0.380638
# Betbrain over/under bookies       0.225134      0.008659    0.006475
# Betbrain max >2.5                 0.030439      0.179924    0.125542
# Betbrain average >2.5             0.021737      0.185776    0.115177
# Betbrain max <2.5                 0.006601      0.201014    0.147049
# Betbrain average <2.5             0.011049      0.199980    0.153435
# Betbrain Asian bookies            0.299957      0.014367    0.128893
# Betbrain Asian home handicap      0.038255      0.105207    0.427120
# Betbrain max Asian home odds      0.016566      0.144615    0.092330
# Betbrain average Asian home odds  0.001861      0.146017    0.082895
# Betbrain max Asian away odds      0.003510      0.120468    0.102839
# Betbrain average Asian away odds  0.010629      0.141623    0.097028
# Div_Cat                                NaN           NaN         NaN
# Date_Cat                               NaN      0.076932    0.061661
# HomeTeam_Cat                           NaN           NaN    0.144005
# result_cat                             NaN           NaN         NaN
# AwayTeam_Cat                           NaN           NaN         NaN
#
#                                   AwayTeam_Cat
# id                                    0.003878
# Bet365 home odds                      0.191977
# Bet365 draw odds                      0.033212
# Bet365 away odds                      0.058628
# Bet&Win home odds                     0.191561
# Bet&Win draw odds                     0.026832
# Bet&Win away odds                     0.050371
# gamebookers home odds                 0.186958
# gamebookers draw odds                 0.033677
# gamebookers away odds                 0.060028
# Interwetten home odds                 0.193497
# Interwetten draw odds                 0.032785
# Interwetten away odds                 0.081053
# Ladbrokes home odds                   0.167065
# Ladbrokes draw odds                   0.029204
# Ladbrokes away odds                   0.063464
# Sportingbet home odds                 0.191431
# Sportingbet draw odds                 0.031941
# Sportingbet away odds                 0.056014
# Will Hill home odds                   0.175472
# Will Hill draw odds                   0.059202
# Will Hill away odds                   0.062904
# Stan James home odds                  0.197277
# Stan James draw odds                  0.025036
# Stan James away odds                  0.070749
# VC Bet home odds                      0.184068
# VC Bet draw odds                      0.035026
# VC Bet away odds                      0.076244
# Betbrain 1X2 bookies                  0.034605
# Betbrain max home odds                0.182211
# Betbrain average home odds            0.186951
# Betbrain max draw odds                0.008172
# Betbrain average draw odds            0.034491
# Betbrain max away odds                0.052834
# Betbrain average draw odds.1          0.063995
# Betbrain over/under bookies           0.056090
# Betbrain max >2.5                     0.046432
# Betbrain average >2.5                 0.056591
# Betbrain max <2.5                     0.040276
# Betbrain average <2.5                 0.048986
# Betbrain Asian bookies                0.057275
# Betbrain Asian home handicap          0.145502
# Betbrain max Asian home odds          0.063219
# Betbrain average Asian home odds      0.045787
# Betbrain max Asian away odds          0.041215
# Betbrain average Asian away odds      0.048005
# Div_Cat                                    NaN
# Date_Cat                              0.006958
# HomeTeam_Cat                          0.023449
# result_cat                            0.062998
# AwayTeam_Cat                               NaN
#
# [51 rows x 51 columns]

# %%
to_drop = [column for column in upper_tri.columns if any((upper_tri[column] > 0.85)&(upper_tri[column] <0.9))]
to_drop
# Out:
# ['Bet&Win draw odds',
#  'Bet&Win away odds',
#  'gamebookers draw odds',
#  'gamebookers away odds',
#  'Interwetten away odds',
#  'Ladbrokes draw odds',
#  'Ladbrokes away odds',
#  'Sportingbet draw odds',
#  'Sportingbet away odds',
#  'Stan James draw odds',
#  'Stan James away odds',
#  'VC Bet draw odds',
#  'VC Bet away odds',
#  'Betbrain max draw odds',
#  'Betbrain average draw odds',
#  'Betbrain max away odds',
#  'Betbrain average draw odds.1',
#  'Betbrain over/under bookies',
#  'Betbrain average <2.5',
#  'Betbrain Asian home handicap',
#  'Betbrain max Asian away odds']

# %%
df_train
# Out:
#       id  Bet365 home odds  Bet365 draw odds  Bet365 away odds  \
# 0     97               2.1              3.20              3.50
# 1     86               1.5              3.75              7.00
# 2     46               2.6              3.25              2.60
# 3    180               2.1              3.25              3.40
# 4    266               2.4              3.25              2.80
# ..   ...               ...               ...               ...
# 261  368               5.5              3.60              1.61
# 262   48               2.2              3.10              3.30
# 263  260               3.1              3.25              2.25
# 264  312               1.9              3.30              4.00
# 265  207               2.0              3.20              3.75
#
#      Bet&Win home odds  Bet&Win draw odds  Bet&Win away odds  \
# 0                 2.05               3.15               3.40
# 1                 1.40               4.00               7.25
# 2                 2.30               3.20               2.80
# 3                 2.10               3.10               3.30
# 4                 2.40               3.10               2.75
# ..                 ...                ...                ...
# 261               5.90               3.50               1.55
# 262               2.05               3.25               3.25
# 263               3.10               3.10               2.20
# 264               1.80               3.15               4.40
# 265               1.85               3.15               4.10
#
#      gamebookers home odds  gamebookers draw odds  gamebookers away odds  ...  \
# 0                     2.10                   3.20                   3.45  ...
# 1                     1.44                   3.75                   7.50  ...
# 2                     2.60                   3.20                   2.60  ...
# 3                     2.10                   3.20                   3.40  ...
# 4                     2.40                   3.20                   2.85  ...
# ..                     ...                    ...                    ...  ...
# 261                   5.50                   3.50                   1.62  ...
# 262                   2.10                   3.25                   3.40  ...
# 263                   3.10                   3.20                   2.25  ...
# 264                   1.90                   3.25                   4.10  ...
# 265                   2.00                   3.25                   3.75  ...
#
#      Betbrain Asian home handicap  Betbrain max Asian home odds  \
# 0                           -0.25                          2.04
# 1                           -1.00                          1.95
# 2                            0.00                          2.00
# 3                           -0.25                          1.92
# 4                            0.00                          1.80
# ..                            ...                           ...
# 261                          0.75                          2.08
# 262                         -0.25                          1.95
# 263                          0.25                          1.91
# 264                         -0.50                          2.00
# 265                         -0.25                          2.00
#
#      Betbrain average Asian home odds  Betbrain max Asian away odds  \
# 0                                1.94                          1.98
# 1                                1.88                          2.08
# 2                                1.92                          1.97
# 3                                1.88                          2.01
# 4                                1.76                          2.14
# ..                                ...                           ...
# 261                              2.05                          1.86
# 262                              1.89                          2.02
# 263                              1.89                          2.03
# 264                              1.96                          1.93
# 265                              1.95                          1.98
#
#      Betbrain average Asian away odds  Div_Cat  Date_Cat  HomeTeam_Cat  \
# 0                                1.92        0        88             9
# 1                                1.96        0        67             0
# 2                                1.91        0        50            12
# 3                                1.98        0        85             8
# 4                                2.05        0        76             4
# ..                                ...      ...       ...           ...
# 261                              1.81        0        23            16
# 262                              1.97        0        50             8
# 263                              1.98        0        73             1
# 264                              1.89        0        14             8
# 265                              1.93        0        38             9
#
#      result_cat  AwayTeam_Cat
# 0             0             2
# 1             2            16
# 2             1             6
# 3             1            12
# 4             0            19
# ..          ...           ...
# 261           0             0
# 262           0            14
# 263           2             0
# 264           0             3
# 265           2            13
#
# [266 rows x 51 columns]

# %%
df_train.drop(['Bet&Win draw odds','Bet&Win away odds','gamebookers draw odds','VC Bet away odds','Betbrain max draw odds','Betbrain average draw odds','Betbrain max away odds','Betbrain average draw odds.1','Betbrain over/under bookies','Betbrain average <2.5','Betbrain Asian home handicap','Betbrain max Asian away odds'], axis=1, inplace=True)

# %%
df_train
# Out:
#       id  Bet365 home odds  Bet365 draw odds  Bet365 away odds  \
# 0     97               2.1              3.20              3.50
# 1     86               1.5              3.75              7.00
# 2     46               2.6              3.25              2.60
# 3    180               2.1              3.25              3.40
# 4    266               2.4              3.25              2.80
# ..   ...               ...               ...               ...
# 261  368               5.5              3.60              1.61
# 262   48               2.2              3.10              3.30
# 263  260               3.1              3.25              2.25
# 264  312               1.9              3.30              4.00
# 265  207               2.0              3.20              3.75
#
#      Bet&Win home odds  gamebookers home odds  gamebookers away odds  \
# 0                 2.05                   2.10                   3.45
# 1                 1.40                   1.44                   7.50
# 2                 2.30                   2.60                   2.60
# 3                 2.10                   2.10                   3.40
# 4                 2.40                   2.40                   2.85
# ..                 ...                    ...                    ...
# 261               5.90                   5.50                   1.62
# 262               2.05                   2.10                   3.40
# 263               3.10                   3.10                   2.25
# 264               1.80                   1.90                   4.10
# 265               1.85                   2.00                   3.75
#
#      Interwetten home odds  Interwetten draw odds  Interwetten away odds  ...  \
# 0                     2.00                    3.1                    3.2  ...
# 1                     1.50                    3.7                    5.7  ...
# 2                     2.40                    3.0                    2.6  ...
# 3                     2.10                    3.0                    3.1  ...
# 4                     2.40                    3.1                    2.7  ...
# ..                     ...                    ...                    ...  ...
# 261                   4.80                    3.6                    1.6  ...
# 262                   2.10                    3.0                    3.1  ...
# 263                   2.80                    3.1                    2.3  ...
# 264                   1.80                    3.2                    4.0  ...
# 265                   1.85                    3.3                    3.7  ...
#
#      Betbrain max <2.5  Betbrain Asian bookies  Betbrain max Asian home odds  \
# 0                 1.80                      29                          2.04
# 1                 1.91                      27                          1.95
# 2                 1.71                      26                          2.00
# 3                 1.76                      23                          1.92
# 4                 1.80                      19                          1.80
# ..                 ...                     ...                           ...
# 261               1.80                      20                          2.08
# 262               1.80                      27                          1.95
# 263               1.70                      21                          1.91
# 264               2.03                      21                          2.00
# 265               1.76                      20                          2.00
#
#      Betbrain average Asian home odds  Betbrain average Asian away odds  \
# 0                                1.94                              1.92
# 1                                1.88                              1.96
# 2                                1.92                              1.91
# 3                                1.88                              1.98
# 4                                1.76                              2.05
# ..                                ...                               ...
# 261                              2.05                              1.81
# 262                              1.89                              1.97
# 263                              1.89                              1.98
# 264                              1.96                              1.89
# 265                              1.95                              1.93
#
#      Div_Cat  Date_Cat  HomeTeam_Cat  result_cat  AwayTeam_Cat
# 0          0        88             9           0             2
# 1          0        67             0           2            16
# 2          0        50            12           1             6
# 3          0        85             8           1            12
# 4          0        76             4           0            19
# ..       ...       ...           ...         ...           ...
# 261        0        23            16           0             0
# 262        0        50             8           0            14
# 263        0        73             1           2             0
# 264        0        14             8           0             3
# 265        0        38             9           2            13
#
# [266 rows x 39 columns]

# %%
X=df_train.drop(['result_cat'],axis=1)
y=df_train['result_cat']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.svm import NuSVC
a = NuSVC()
a.fit(X_train,y_train)
# Out:
# NuSVC()

# %%
X1_test=pd.read_csv('/kaggle/input/the-data-alchemist-techweek-23/test.csv')
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
X1_test['Div_Cat'] = labelencoder.fit_transform(X1_test['Div'])
X1_test['Date_Cat'] = labelencoder.fit_transform(X1_test['Date'])
X1_test['HomeTeam_Cat'] = labelencoder.fit_transform(X1_test['HomeTeam'])
X1_test['AwayTeam_Cat'] = labelencoder.fit_transform(X1_test['AwayTeam'])

# %%
X1_test.drop(['Bet&Win draw odds','Bet&Win away odds','gamebookers draw odds','VC Bet away odds','Betbrain max draw odds','Betbrain average draw odds','Betbrain max away odds','Betbrain average draw odds.1','Betbrain over/under bookies','Betbrain average <2.5','Betbrain Asian home handicap','Betbrain max Asian away odds'], axis=1, inplace=True)

# %%
X1_test.drop(['Div','Date','HomeTeam','AwayTeam'],axis=1,inplace=True)
predictions = a.predict(X1_test)
predictions
# Out:
# array([1, 2, 0, 1, 2, 1, 2, 2, 2, 1, 1, 2, 1, 2, 1, 0, 2, 2, 2, 1, 0, 1,
#        1, 0, 2, 2, 2, 2, 0, 1, 0, 0, 2, 2, 2, 2, 2, 2, 1, 2, 0, 2, 2, 0,
#        2, 2, 2, 1, 2, 2, 2, 1, 2, 0, 2, 2, 1, 2, 2, 2, 2, 1, 1, 2, 2, 2,
#        2, 2, 1, 2, 2, 0, 0, 1, 2, 2, 1, 0, 2, 2, 0, 2, 2, 2, 0, 0, 2, 2,
#        2, 2, 0, 0, 0, 2, 1, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 2, 0, 2, 1, 2,
#        0, 2, 2, 0])

# %%
x_n=np.array(predictions)
x_n
# Out:
# array([1, 2, 0, 1, 2, 1, 2, 2, 2, 1, 1, 2, 1, 2, 1, 0, 2, 2, 2, 1, 0, 1,
#        1, 0, 2, 2, 2, 2, 0, 1, 0, 0, 2, 2, 2, 2, 2, 2, 1, 2, 0, 2, 2, 0,
#        2, 2, 2, 1, 2, 2, 2, 1, 2, 0, 2, 2, 1, 2, 2, 2, 2, 1, 1, 2, 2, 2,
#        2, 2, 1, 2, 2, 0, 0, 1, 2, 2, 1, 0, 2, 2, 0, 2, 2, 2, 0, 0, 2, 2,
#        2, 2, 0, 0, 0, 2, 1, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 2, 0, 2, 1, 2,
#        0, 2, 2, 0])

# %%
df_n = pd.DataFrame(x_n, columns = ['Result'])

# %%
df_n
# Out:
#      Result
# 0         1
# 1         2
# 2         0
# 3         1
# 4         2
# ..      ...
# 109       2
# 110       0
# 111       2
# 112       2
# 113       0
#
# [114 rows x 1 columns]

# %%
df_n['Result'] = df_n['Result'].replace([0, 1,2], ['A', 'D','H'])

# %%
df_n
# Out:
#     Result
# 0        D
# 1        H
# 2        A
# 3        D
# 4        H
# ..     ...
# 109      H
# 110      A
# 111      H
# 112      H
# 113      A
#
# [114 rows x 1 columns]

# %%
output = pd.DataFrame({'id': X1_test.id,
                       'result': df_n.Result})

# %%
output
# Out:
#       id result
# 0    336      D
# 1    104      H
# 2     40      A
# 3    364      D
# 4    234      H
# ..   ...    ...
# 109  102      H
# 110  178      A
# 111   76      H
# 112  200      H
# 113  251      A
#
# [114 rows x 2 columns]

# %%
output.to_csv('submission96.csv', index=False)
